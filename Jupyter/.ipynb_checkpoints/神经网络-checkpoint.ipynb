# %%
# 必要的库
import tensorflow as tf
import numpy as np
import pandas as pd

#加载数据
TRAINING = pd.read_csv("../input/train.csv")
TESTING = pd.read_csv("../input/test.csv")
# 将sub 数据换成０，１，２，３
sub_map = {0:0,1000:1,1500:2,2000:3}
def change(c): return sub_map[c]
TRAINING['sub'] = TRAINING['sub'].apply(change)

# %%
TRAINING.head(12)
# Out:
#         rank    card01    card02    card03    card04    card05    card06  \
# 0   0.028583  0.165071  0.206147  0.037460  0.067232  0.000000  0.000232
# 1   0.028906  0.204216  0.206147  0.143891  0.041626  0.035280  0.074515
# 2   0.977678  0.378936  0.206147  0.189028  0.382020  0.000000  0.002010
# 3   0.980677  0.479036  0.354542  0.050477  0.744133  0.000000  0.227564
# 4   0.020882  0.199131  0.206147  0.120989  0.117432  0.001565  0.000000
# 5   0.021295  0.197396  0.206147  0.059829  0.145270  0.000000  0.003092
# 6   0.038031  0.110026  0.206147  0.029027  0.041425  0.000000  0.013682
# 7   0.379728  0.211187  0.206147  0.018064  0.109688  0.052498  0.000000
# 8   0.404205  0.104566  0.206147  0.042608  0.045153  0.000000  0.000000
# 9   0.596181  0.374197  0.206147  0.130531  0.156654  0.012041  0.000386
# 10  0.737491  0.362005  0.206147  0.031201  0.167991  0.054666  0.034939
# 11  0.768108  0.211446  0.206147  0.129821  0.079791  0.005455  0.002164
#
#     card07    card08    card09    card10    card11    card12  sub
# 0      0.0  0.127456  0.000000  0.004542  0.189634  0.114260    0
# 1      0.0  0.036452  0.020924  0.008308  0.116150  0.170142    0
# 2      0.0  0.675134  0.003763  0.014707  0.002258  0.225304    0
# 3      0.0  0.048266  0.019921  0.013411  0.000000  0.319962    0
# 4      0.0  0.148463  0.054661  0.053135  0.054834  0.144563    0
# 5      0.0  0.302009  0.007727  0.060631  0.024323  0.129370    0
# 6      0.0  0.002717  0.000000  0.005502  0.141864  0.082885    0
# 7      0.0  0.046016  0.004098  0.012591  0.153527  0.168487    0
# 8      0.0  0.063958  0.000000  0.004800  0.080444  0.078307    0
# 9      0.0  0.052965  0.006172  0.020235  0.105761  0.331331    1
# 10     0.0  0.137045  0.003563  0.041762  0.071162  0.314434    2
# 11     0.0  0.049146  0.008580  0.017355  0.196278  0.160151    1

# %%
# 将数据转换成tensor格式方便TF的计算
feature_list = TESTING.columns.values.tolist()
def input_fn(df):
    feature_cols  = {k: tf.constant(df[k].values)
                     for k in feature_list}
    label = tf.constant(df['sub'].values)
    return feature_cols, label

def input_fn2(df):
    feature_cols  = {k: tf.constant(df[k].values)
                     for k in feature_list}
    return feature_cols

# %%
# Specify that all features have real-value data
rank = tf.contrib.layers.real_valued_column("rank")
card01 = tf.contrib.layers.real_valued_column("card01")
card02 = tf.contrib.layers.real_valued_column("card02")
card03 = tf.contrib.layers.real_valued_column("card03")
card04 = tf.contrib.layers.real_valued_column("card04")
card05 = tf.contrib.layers.real_valued_column("card05")
card06 = tf.contrib.layers.real_valued_column("card06")
card07 = tf.contrib.layers.real_valued_column("card07")
card08 = tf.contrib.layers.real_valued_column("card08")
card09 = tf.contrib.layers.real_valued_column("card09")
card10 = tf.contrib.layers.real_valued_column("card10")
card11 = tf.contrib.layers.real_valued_column("card11")
card12 = tf.contrib.layers.real_valued_column("card12")

feature_columns = [rank,card01,card02,card03,card04,card05,card06,card07,card08,card09,card10,card11,card12]
# 创建一个基本的神经网络
classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[13, 26, 13],
                                            n_classes=4,
                                            model_dir="/tmp/sub_model")
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_is_chief': True, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f04b0663a58>, 'keep_checkpoint_every_n_hours': 10000, 'save_checkpoints_secs': 600, 'save_summary_steps': 100, 'keep_checkpoint_max': 5, 'save_checkpoints_steps': None, '_master': '', '_environment': 'local', '_task_type': None, '_num_ps_replicas': 0, 'tf_random_seed': None, 'tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_evaluation_master': ''}

# %%
classifier.fit(input_fn=lambda: input_fn(TRAINING),steps=2000)
# Out:
# WARNING:tensorflow:From /home/xiaqiang/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:315 in fit.: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/xiaqiang/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:315 in fit.: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/xiaqiang/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:315 in fit.: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# INFO:tensorflow:Summary name dnn/hiddenlayer_0:fraction_of_zero_values is illegal; using dnn/hiddenlayer_0_fraction_of_zero_values instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_0:activation is illegal; using dnn/hiddenlayer_0_activation instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_1:fraction_of_zero_values is illegal; using dnn/hiddenlayer_1_fraction_of_zero_values instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_1:activation is illegal; using dnn/hiddenlayer_1_activation instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_2:fraction_of_zero_values is illegal; using dnn/hiddenlayer_2_fraction_of_zero_values instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_2:activation is illegal; using dnn/hiddenlayer_2_activation instead.
# INFO:tensorflow:Summary name dnn/logits:fraction_of_zero_values is illegal; using dnn/logits_fraction_of_zero_values instead.
# INFO:tensorflow:Summary name dnn/logits:activation is illegal; using dnn/logits_activation instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:loss = 1.41323, step = 1
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/sub_model/model.ckpt.
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# INFO:tensorflow:loss = 0.562752, step = 101
# INFO:tensorflow:global_step/sec: 72.147
# INFO:tensorflow:loss = 0.548076, step = 201
# INFO:tensorflow:global_step/sec: 104.969
# INFO:tensorflow:loss = 0.540972, step = 301
# INFO:tensorflow:global_step/sec: 105.452
# INFO:tensorflow:loss = 0.537354, step = 401
# INFO:tensorflow:global_step/sec: 104.465
# INFO:tensorflow:loss = 0.534651, step = 501
# INFO:tensorflow:global_step/sec: 104.511
# INFO:tensorflow:loss = 0.53202, step = 601
# INFO:tensorflow:global_step/sec: 104.723
# INFO:tensorflow:loss = 0.529402, step = 701
# INFO:tensorflow:global_step/sec: 105.516
# INFO:tensorflow:loss = 0.526834, step = 801
# INFO:tensorflow:global_step/sec: 105.223
# INFO:tensorflow:loss = 0.524051, step = 901
# INFO:tensorflow:global_step/sec: 104.691
# INFO:tensorflow:loss = 0.52201, step = 1001
# INFO:tensorflow:global_step/sec: 104.783
# INFO:tensorflow:loss = 0.520376, step = 1101
# INFO:tensorflow:global_step/sec: 104.426
# INFO:tensorflow:loss = 0.519043, step = 1201
# INFO:tensorflow:global_step/sec: 88.6486
# INFO:tensorflow:loss = 0.517929, step = 1301
# INFO:tensorflow:global_step/sec: 103.884
# INFO:tensorflow:loss = 0.516922, step = 1401
# INFO:tensorflow:global_step/sec: 104.662
# INFO:tensorflow:loss = 0.516077, step = 1501
# INFO:tensorflow:global_step/sec: 81.1536
# INFO:tensorflow:loss = 0.515324, step = 1601
# INFO:tensorflow:global_step/sec: 77.9353
# INFO:tensorflow:loss = 0.514413, step = 1701
# INFO:tensorflow:global_step/sec: 104.72
# INFO:tensorflow:loss = 0.513421, step = 1801
# INFO:tensorflow:global_step/sec: 103.676
# INFO:tensorflow:loss = 0.512586, step = 1901
# INFO:tensorflow:global_step/sec: 104.874
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/sub_model/model.ckpt.
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# INFO:tensorflow:Loss for final step: 0.51198.

# %%
y = pd.Series(classifier.predict(input_fn=lambda: input_fn2(TESTING), as_iterable=True))
# Out:
# WARNING:tensorflow:From /home/xiaqiang/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:348 in predict.: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/xiaqiang/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:348 in predict.: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/xiaqiang/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:348 in predict.: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with as_iterable is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# INFO:tensorflow:Summary name dnn/hiddenlayer_0:fraction_of_zero_values is illegal; using dnn/hiddenlayer_0_fraction_of_zero_values instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_0:activation is illegal; using dnn/hiddenlayer_0_activation instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_1:fraction_of_zero_values is illegal; using dnn/hiddenlayer_1_fraction_of_zero_values instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_1:activation is illegal; using dnn/hiddenlayer_1_activation instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_2:fraction_of_zero_values is illegal; using dnn/hiddenlayer_2_fraction_of_zero_values instead.
# INFO:tensorflow:Summary name dnn/hiddenlayer_2:activation is illegal; using dnn/hiddenlayer_2_activation instead.
# INFO:tensorflow:Summary name dnn/logits:fraction_of_zero_values is illegal; using dnn/logits_fraction_of_zero_values instead.
# INFO:tensorflow:Summary name dnn/logits:activation is illegal; using dnn/logits_activation instead.

# %%
list(y)
# Out:
# INFO:tensorflow:Loading model from checkpoint: /tmp/sub_model/model.ckpt-2000-?????-of-00001.

# %%
y
