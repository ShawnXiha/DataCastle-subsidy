# %%
import pandas as pd 
import warnings 
warnings.filterwarnings("ignore")
card =  pd.read_csv("../input/cleaned_card.csv",index_col='学生id',encoding='utf-8')
score =  pd.read_csv("../input/cleaned_score.csv",index_col='学生id',encoding='utf-8')
data = pd.concat([score,card],axis =1).drop('学院编号', 1)

# %%
data.head(10)
# Out:
#           成绩排名      消费金额      其他     图书馆       开水   教务处   文印中心  校医院       校车  \
# 学生id
# 0    -1.681326   4997.56    0.00   84.40   429.58   0.0    0.3  0.0   417.49
# 1    -1.680156   6182.69    0.00  324.20   265.97  29.3   96.4  0.0   119.40
# 2     0.143542   4966.65    0.01   22.40   670.36   0.0    0.0  0.0    34.88
# 3     1.629171     42.40    0.00    0.00     0.18   0.0    0.0  0.0     0.00
# 8     1.749205  11472.37    0.00  425.90  2440.94   0.0    2.6  0.0  2211.45
# 9     1.760045  14502.91  122.26  113.73  4754.68   0.0  294.4  0.0   158.10
# 10   -1.709162   6028.74    0.00  272.60   750.34   1.3    0.0  0.0   486.30
# 11   -1.707670   5976.20    0.00  134.80   928.21   0.0    4.0  0.0   989.25
# 16   -1.747632   2974.56    0.00   38.82   914.81   0.0    5.0  3.0   291.60
# 17   -1.742198    495.85    0.00    9.50    67.05   0.0    0.0  0.0    59.00
#
#         洗衣房      淋浴      超市       食堂
# 学生id
# 0      0.00   12.30  839.68  3213.81
# 1     25.02   22.50  514.30  4785.60
# 2     22.20   53.10  829.95  3333.75
# 3      7.62   34.60    0.00     0.00
# 8      4.50   39.83   10.00  6337.15
# 9     23.82   36.32    0.00  8999.60
# 10    65.36  143.90  242.80  4066.14
# 11     9.24  164.20  107.70  3638.80
# 16     0.00   48.00   14.00  1659.33
# 17    21.60   23.90   14.80   300.00

# %%
data.isnull().sum()
# Out:
# 成绩排名    3538
# 消费金额      37
# 其他        37
# 图书馆       37
# 开水        37
# 教务处       37
# 文印中心      37
# 校医院       37
# 校车        37
# 洗衣房       37
# 淋浴        37
# 超市        37
# 食堂        37
# dtype: int64

# %%
# 使用均值替换nan
data.fillna(data.mean(),inplace=True)
data.isnull().sum()
# Out:
# 成绩排名    0
# 消费金额    0
# 其他      0
# 图书馆     0
# 开水      0
# 教务处     0
# 文印中心    0
# 校医院     0
# 校车      0
# 洗衣房     0
# 淋浴      0
# 超市      0
# 食堂      0
# dtype: int64

# %%
ID_test =  pd.read_csv("../input/studentID_test.csv",encoding='utf-8')
ID_sub_train = pd.read_csv("../input/subsidy_train.csv",encoding='utf-8')

# %%
ID_sub_train.head()
# Out:
#    学生id  助学金金额
# 0     0      0
# 1     1      0
# 2     8      0
# 3     9      0
# 4    10      0

# %%
X_test = data.loc[ID_test.学生id,:]
X_train = data.loc[ID_sub_train.学生id,:]
y_train = ID_sub_train.助学金金额

# %%
print(X_test.shape,X_train.shape,y_train.shape)
# Out:
# (10783, 13) (10885, 13) (10885,)

# %%
X_test.to_pickle('../input/X_test.pkl')
X_train.to_pickle('../input/X_train.pkl')
y_train.to_pickle('../input/y_train.pkl')
